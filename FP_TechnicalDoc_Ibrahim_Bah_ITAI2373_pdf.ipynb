# %% [markdown]
# <a href="https://colab.research.google.com/github/stillrahim/jupyter-exploration/blob/main/FP_TechnicalDoc_Ibrahim_Bah_ITAI2373_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
NewsBot/
│── data/
│   ├── raw/
│   ├── processed/
│── notebooks/
│   ├── preprocessing.ipynb
│   ├── classification.ipynb
│   ├── ner_sentiment.ipynb
│   ├── multimodal_final.ipynb
│── src/
│   ├── preprocess.py
│   ├── sentiment.py
│   ├── classifier.py
│   ├── topic_modeling.py
│   ├── ner.py
│   ├── summarize.py
│   ├── semantic_search.py
│── app/
│   ├── chatbot_interface.py
│── README.md
# Out:
#   File "/tmp/ipython-input-1288321332.py", line 2
#     │── data/
#     ^
# SyntaxError: invalid character '│' (U+2502)

# %%
git clone https://github.com/IbrahimBah/NewsBot.git
cd NewsBot

pip install -r requirements.txt
python -m spacy download en_core_web_sm

# %%
python src/preprocess.py

# %%
python src/classifier.py

# %%
python src/sentiment.py
python src/ner.py

# %%
python src/semantic_search.py

# %%
python app/chatbot_interface.py

# %%
/visuals
